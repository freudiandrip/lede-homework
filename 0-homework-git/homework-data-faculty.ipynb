# %% [markdown]
# # Scraping Intro Homework: Columbia J-School Data Faculty
#
# In this assignment, we'll practicing our scraping skills by examining the Columbia Journalism School's listing of data faculty: https://journalism.columbia.edu/faculty?expertise=116

# %% [markdown]
# ### 0) Setup
#
# Import `requests`, `BeautifulSoup`, and `pandas`. Remember that even though we installed the library as `pip install beautifulsoup4`, the import statement we practiced is slightly different.

# %%
import requests
import pandas as pd
import lxml.html
import pprint as pp

# %% [markdown]
# ### 1) Grab the HTML for the webpage linked above
#
# Use `requests` to get the HTML, assigning it to a variable

# %%
URL = "https://journalism.columbia.edu/faculty?expertise=116"
page = requests.get(URL).text
pp.pprint(page)
# Out:
# ('<!DOCTYPE html>\n'
#  '<html lang="en" dir="ltr">\n'
#  '<head>\n'
#  '\t\n'
#  '<!-- Google tag (gtag.js) -->\n'
#  '<script async '
#  'src="https://www.googletagmanager.com/gtag/js?id=G-KQW8XM5VEJ"></script>\n'
#  '<script>\n'
#  '  window.dataLayer = window.dataLayer || [];\n'
#  '  function gtag(){dataLayer.push(arguments);}\n'
#  "  gtag('js', new Date());\n"
#  '\n'
#  "  gtag('config', 'G-KQW8XM5VEJ');\n"
#  '</script>\n'
#  '\n'
#  '<!-- Anti-flicker snippet (recommended) INC1425337\xa0-->\n'
#  '<style>.async-hide { opacity: 0 !important} </style>\n'
#  "<script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;\n"
#  "h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};\n"
#  '(a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;\n'
#  "})(window,document.documentElement,'async-hide','dataLayer',4000,\n"
#  "{'GTM-MV2DS4J':true});</script>\n"
#  '<!-- Modified Analytics tracking code with Optimize plugin INC1425337 -->\n'
#  '\xa0 \xa0 <script>\n'
#  '\xa0 \xa0 '
#  "(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){\n"
#  '\xa0 \xa0 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new '
#  'Date();a=s.createElement(o),\n'
#  '\xa0 \xa0 '
#  'm=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n'
#  '\xa0 \xa0 '
#  "})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');\n"
#  '\n'
#  "\xa0 \xa0 ga('create', 'UA-2152699-1', 'auto');\n"
#  "\xa0 \xa0 ga('require', 'GTM-MV2DS4J');\n"
#  "\xa0 \xa0 ga('send', 'pageview');\n"
#  '\xa0 \xa0 </script>\n'
#  '\n'
#  '    \n'
#  '  <link rel="profile" href="http://www.w3.org/1999/xhtml/vocab" />\n'
#  '  <link rel="shortcut icon" href="sites/all/themes/soj/favicon.ico" '
#  'type="image/x-icon" />\n'
#  '  <meta charset="utf-8">\n'
#  '  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n'
#  '  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n'
#  '<link rel="stylesheet" '
#  'href="https://search.sites.columbia.edu/cu-privacy-notice/cu-privacy-notice.css" '
#  '/>\n'
#  '<meta name="description" content="Apply to join the adjunct faculty." />\n'
#  '<meta name="generator" content="Drupal 7 (http://drupal.org)" />\n'
#  '<link rel="canonical" href="https://journalism.columbia.edu/faculty" />\n'
#  '<link rel="shortlink" href="https://journalism.columbia.edu/node/224" />\n'
#  '  <title>Faculty | Columbia Journalism School</title>\n'
#  '  <link type="text/css" rel="stylesheet" '
#  'href="https://journalism.columbia.edu/files/soj/css/css_lQaZfjVpwP_oGNqdtWCSpJT1EMqXdMiU84ekLLxQnc4.css" '
#  'media="all" />\n'
#  '<link type="text/css" rel="stylesheet" '
#  'href="https://journalism.columbia.edu/files/soj/css/css_vx_lUTOrixRFV0IibJIJH6l9o_jxPeFqJnTLfyD-t5A.css" '
#  'media="all" />\n'
#  '<link type="text/css" rel="stylesheet" '
#  'href="https://journalism.columbia.edu/files/soj/css/css_4H0iqLlLeWgKWSjEhaSEvQETRntLTZ3eFK03eM1Tdow.css" '
#  'media="all" />\n'
#  '<link type="text/css" rel="stylesheet" '
#  'href="//cdn.jsdelivr.net/bootstrap/3.3.5/css/bootstrap.min.css" media="all" '
#  '/>\n'
#  '<link type="text/css" rel="stylesheet" '
#  'href="https://journalism.columbia.edu/files/soj/css/css_mPk7XOP-okjahGV6N-hvD-TJOLwAf2bQT981NqZp3BQ.css" '
#  'media="all" />\n'
#  '  <!-- HTML5 element support for IE6-8 -->\n'
#  '  <!--[if lt IE 9]>\n'
#  '    <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script>\n'
#  '  <![endif]-->\n'
#  '  <script '
#  'src="https://journalism.columbia.edu/files/soj/js/js_5qJ7vtdMOojWzE0nHHZPu7U25TwaeTO-zilPLqTCfxA.js"></script>\n'
#  '<script '
#  'src="https://journalism.columbia.edu/files/soj/js/js_v83iJArb6joEK8u_NI4UrTcB7QWJYZCAKeXIpYtlMKY.js"></script>\n'
#  '<script '
#  'src="https://journalism.columbia.edu/files/soj/js/js_IS7qw1YjorrYWIEuB2_bh_V4g403Robisbo_jO2gRF8.js"></script>\n'
#  '<script '
#  'src="//cdn.jsdelivr.net/bootstrap/3.3.5/js/bootstrap.min.js"></script>\n'
#  '<script '
#  'src="https://journalism.columbia.edu/files/soj/js/js_xHCA20lBouUjejE78OQmNW2XkhYrCDRoH_-SKteHhns.js"></script>\n'
#  '<script '
#  'src="https://journalism.columbia.edu/files/soj/js/js_SMgteoB7ZTsstvqfvMm6p7m-JpkMDRIBXEZ8yw_o7rU.js"></script>\n'
#  '<script '
#  'src="https://journalism.columbia.edu/files/soj/js/js_PzpujahHxLw7fwJH_wNKLWkoKwlQfZltCaRc87w1aig.js"></script>\n'
#  '<script '
#  'src="https://journalism.columbia.edu/files/soj/js/js_mBQQnv2jfT7hV2YFgICrM1KFECoRoI4UlzREm5pJWyg.js"></script>\n'
#  '<script>jQuery.extend(Drupal.settings, '
#  '{"basePath":"\\/","pathPrefix":"","setHasJsCookie":0,"ajaxPageState":{"theme":"soj","theme_token":"9CHQKDeu1kO1L7i3iA0aNobmK0aFSzxJfflEYUfpRfc","jquery_version":"1.10","js":{"sites\\/all\\/themes\\/bootstrap\\/js\\/bootstrap.js":1,"public:\\/\\/google_tag\\/google_tag.script.js":1,"sites\\/all\\/modules\\/contrib\\/jquery_update\\/replace\\/jquery\\/1.10\\/jquery.min.js":1,"misc\\/jquery-extend-3.4.0.js":1,"misc\\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\\/jquery.once.js":1,"misc\\/drupal.js":1,"sites\\/all\\/modules\\/contrib\\/jquery_update\\/replace\\/ui\\/ui\\/minified\\/jquery.ui.effect.min.js":1,"sites\\/all\\/modules\\/contrib\\/jquery_update\\/replace\\/ui\\/external\\/jquery.cookie.js":1,"sites\\/all\\/modules\\/contrib\\/jquery_update\\/replace\\/misc\\/jquery.form.min.js":1,"sites\\/all\\/modules\\/contrib\\/jquery_update\\/replace\\/ui\\/ui\\/minified\\/jquery.ui.effect-slide.min.js":1,"misc\\/ajax.js":1,"sites\\/all\\/modules\\/contrib\\/jquery_update\\/js\\/jquery_update.js":1,"\\/\\/cdn.jsdelivr.net\\/bootstrap\\/3.3.5\\/js\\/bootstrap.min.js":1,"sites\\/all\\/modules\\/contrib\\/autoupload\\/js\\/autoupload.js":1,"sites\\/all\\/modules\\/ias\\/cu_gcse_embed\\/js\\/cu_gcse_embed.js":1,"sites\\/all\\/modules\\/ias\\/cu_gsa\\/js\\/cu_gsa.js":1,"sites\\/all\\/modules\\/ias\\/cu_soj\\/js\\/cu-soj-main-menu-accessible.js":1,"sites\\/all\\/modules\\/contrib\\/extlink\\/extlink.js":1,"sites\\/all\\/modules\\/ias\\/cu_soj\\/js\\/cu_soj_dropdown.js":1,"sites\\/all\\/modules\\/ias\\/wind\\/wind.js":1,"https:\\/\\/search.sites.columbia.edu\\/cu-privacy-notice\\/cu-privacy-notice.js":1,"sites\\/all\\/modules\\/contrib\\/better_exposed_filters\\/better_exposed_filters.js":1,"sites\\/all\\/modules\\/contrib\\/ctools\\/js\\/auto-submit.js":1,"sites\\/all\\/modules\\/ias\\/cu_bef_addr\\/js\\/jquery-scrollto.js":1,"sites\\/all\\/modules\\/ias\\/cu_bef_addr\\/js\\/jquery.history.js":1,"sites\\/all\\/modules\\/ias\\/cu_bef_addr\\/js\\/cu-bef-addr.js":1,"sites\\/all\\/modules\\/contrib\\/views_load_more\\/views_load_more.js":1,"sites\\/all\\/modules\\/contrib\\/views\\/js\\/base.js":1,"sites\\/all\\/themes\\/bootstrap\\/js\\/misc\\/_progress.js":1,"sites\\/all\\/modules\\/contrib\\/views\\/js\\/ajax_view.js":1,"sites\\/all\\/libraries\\/jquery.hoverIntent.minified.js":1,"sites\\/all\\/libraries\\/jquery.fitvids.js":1,"sites\\/all\\/themes\\/soj\\/js\\/main.js":1,"sites\\/all\\/themes\\/bootstrap\\/js\\/misc\\/ajax.js":1,"sites\\/all\\/themes\\/bootstrap\\/js\\/modules\\/views\\/js\\/ajax_view.js":1},"css":{"modules\\/system\\/system.base.css":1,"sites\\/all\\/modules\\/ias\\/cu_gcse_embed\\/css\\/cu_gcse_embed.css":1,"sites\\/all\\/modules\\/ias\\/cu_gsa\\/css\\/cu_gsa.css":1,"sites\\/all\\/modules\\/contrib\\/date\\/date_api\\/date.css":1,"sites\\/all\\/modules\\/contrib\\/date\\/date_popup\\/themes\\/datepicker.1.7.css":1,"modules\\/field\\/theme\\/field.css":1,"modules\\/node\\/node.css":1,"sites\\/all\\/modules\\/contrib\\/extlink\\/extlink.css":1,"sites\\/all\\/modules\\/contrib\\/views\\/css\\/views.css":1,"sites\\/all\\/modules\\/contrib\\/ctools\\/css\\/ctools.css":1,"sites\\/all\\/libraries\\/fontawesome\\/css\\/font-awesome.css":1,"\\/\\/cdn.jsdelivr.net\\/bootstrap\\/3.3.5\\/css\\/bootstrap.min.css":1,"sites\\/all\\/themes\\/bootstrap\\/css\\/3.3.5\\/overrides.min.css":1,"sites\\/all\\/themes\\/soj\\/css\\/styles.min.css":1,"sites\\/all\\/themes\\/soj\\/css\\/equal-height-columns.css":1}},"wind":{"basePath":"\\/","element":""},"better_exposed_filters":{"datepicker":false,"slider":false,"settings":[],"autosubmit":false,"views":{"courses":{"displays":{"faculty_taught_courses":{"filters":[]}}},"faculties":{"displays":{"block":{"filters":{"expertise":{"required":false}}}}}}},"urlIsAjaxTrusted":{"\\/view\\/faculties":true,"\\/views\\/ajax":true,"\\/search\\/gcse":true},"views":{"ajax_path":"\\/views\\/ajax","ajaxViews":{"views_dom_id:1e64d5d290b5742ee53ae04b1a291ba0":{"view_name":"faculties","view_display_id":"block ...
#  'is '
#  'external)","extImgClass":0,"extSubdomains":0,"extExclude":"","extInclude":"","extCssExclude":"","extCssExplicit":"","extAlert":0,"extAlertText":"This '
#  'link will take you to an external web '
#  'site.","mailtoClass":"mailto","mailtoLabel":"(link sends '
#  'e-mail)"},"where_to_begin_menu":{"collapse":0},"bootstrap":{"anchorsFix":"0","anchorsSmoothScrolling":"0","formHasError":1,"popoverEnabled":1,"popoverOptions":{"animation":1,"html":0,"placement":"right","selector":"","trigger":"click","triggerAutoclose":1,"title":"","content":"","delay":0,"container":"body"},"tooltipEnabled":1,"tooltipOptions":{"animation":1,"html":0,"placement":"auto '
#  'left","selector":"","trigger":"hover '
#  'focus","delay":0,"container":"body"}}});</script>\n'
#  '  <script src="https://use.typekit.net/vpe5dsc.js"></script>\n'
#  '  <script>try{Typekit.load({ async: true });}catch(e){}</script>\n'
#  '  <script type="text/javascript">var _sf_startpt=(new '
#  'Date()).getTime()</script>\n'
#  '  <script async="async" src="https://apply.jrn.columbia.edu/ping"></script>\n'
#  '\n'
#  '  <!-- Global site tag (gtag.js) - Google Analytics -- INC1425337 -->\n'
#  '  <script async '
#  'src="https://www.googletagmanager.com/gtag/js?id=UA-2152699-1"></script>\n'
#  '    <script>\n'
#  '      window.dataLayer = window.dataLayer || [];\n'
#  '      function gtag(){dataLayer.push(arguments);}\n'
#  "      gtag('js', new Date());\n"
#  '      \n'
#  "      gtag('config', 'UA-2152699-1', { 'optimize_id': 'GTM-MV2DS4J'});\n"
#  '    </script>\n'
#  '    <!-- END Global site tag -->\n'
#  '\n'
#  '</head>\n'
#  '<body class="html not-front not-logged-in no-sidebars page-node page-node- '
#  'page-node-224 node-type-page">\n'
#  '  <div id="skip-link">\n'
#  '    <a href="#main-content" class="element-invisible element-focusable">Skip '
#  'to main content</a>\n'
#  '  </div>\n'
#  '    <div class="region region-page-top">\n'
#  '    <noscript aria-hidden="true"><iframe '
#  'src="https://www.googletagmanager.com/ns.html?id=GTM-5TF3RGK" height="0" '
#  'width="0" style="display:none;visibility:hidden"></iframe></noscript>  '
#  '</div>\n'
#  '  <header class="container main-header" id="main-header">\n'
#  '\n'
#  '  <div class="row first-row">\n'
#  '    <div class="hidden-lg col-xs-2 col-sm-1 col-md-1 mobile-menu-icon">\n'
#  '              <button type="button" class="navbar-toggle" '
#  'data-toggle="collapse" aria-hidden="true" data-target=".m-navbar-collapse">\n'
#  '          <span class="sr-only">Toggle navigation</span>\n'
#  '          <span class="icon-bar"></span>\n'
#  '          <span class="icon-bar"></span>\n'
#  '          <span class="icon-bar"></span>\n'
#  '        </button>\n'
#  '          </div>\n'
#  '\n'
#  '    <div role="banner" class="col-xs-8 col-sm-7 col-md-7 col-lg-7" '
#  'id="page-header">\n'
#  '      <div class="cu-branding hidden-xs">\n'
#  '        <a class="gray" href="http://columbia.edu" target="_blank">Columbia '
#  'University in the City of New York</a>\n'
#  '      </div>\n'
#  '      <div class="site-branding">\n'
#  '        <a class="home-link" href="/" title="Home">\n'
#  '          <span class="logo">Columbia Journalism School</span>\n'
#  '        </a>\n'
#  '      </div>\n'
#  '    </div>\n'
#  '    <div class="col-xs-2 col-sm-4 col-md-4 col-lg-4 col-lg-offset-1 '
#  'search-container">\n'
#  '      <button type="button" class="search-toggle hidden-sm hidden-md '
#  'hidden-lg" data-toggle="collapse" data-target=".m-search-collapse">\n'
#  '        <i class="fa fa-search fa-lg" aria-hidden="true"></i>\n'
#  '      </button>\n'
#  '      <div class="hidden-xs">\n'
#  '          <div class="region region-header">\n'
#  '    <section id="block-cu-gcse-embed-cu-gcse-embed-search-form-block" '
#  'class="block block-cu-gcse-embed clearfix">\n'
#  '\n'
#  '      \n'
#  '  <form class="cu-gsa-search-form cu-gcse-embed clearfix" role="search" '
#  'action="/search/gcse" method="get" id="cu-gcse-embed-search-form" '
#  'accept-charset="UTF-8"><div><div class="form-item form-item-query '
#  'form-type-textfield form-group"><input placeholder="Search" class="keyword '
#  'form-control form-text" type="text" id="edit-query" name="query" value="" '
#  'size="60" maxlength="128" /> <label class="control-label element-invisible" '
#  'for="edit-query">Search</label>\n'
#  '</div><button type="submit" id="edit-submit" name="op" value="Search" '
#  'class="btn btn-primary form-submit icon-after"><span '
#  'class="sr-only">Search</span> <span class="glyphicon glyphicon-search" '
#  'aria-hidden="true"></span></button>\n'
#  '<input type="hidden" name="form_build_id" '
#  'value="form--tFG51hEMtr1UVLrUxYo9WX2ZLGV2nXUlxWPogeDFy4" />\n'
#  '<input type="hidden" name="form_id" value="cu_gcse_embed_search_form" />\n'
#  '</div></form>\n'
#  '</section>\n'
#  '  </div>\n'
#  '      </div>\n'
#  '    </div>\n'
#  '  </div>\n'
#  '\n'
#  '  <div class="row m-search-collapse collapse hidden-sm hidden-md '
#  'hidden-lg">\n'
#  '    <div id="search-mobile" class="search-mobile col-sm-12">\n'
#  '        <div class="region region-header">\n'
#  '      <div class="region region-header">\n'
#  '    <section id="block-cu-gcse-embed-cu-gcse-embed-search-form-block" '
#  'class="block block-cu-gcse-embed clearfix">\n'
#  '\n'
#  '      \n'
#  '  <form class="cu-gsa-search-form cu-gcse-embed clearfix" role="search" '
#  'action="/search/gcse" method="get" id="cu-gcse-embed-search-form" '
#  'accept-charset="UTF-8"><div><div class="form-item form-item-query '
#  'form-type-textfield form-group"><input placeholder="Search" class="keyword '
#  'form-control form-text" type="text" id="edit-query" name="query" value="" '
#  'size="60" maxlength="128" /> <label class="control-label element-invisible" '
#  'for="edit-query">Search</label>\n'
#  '</div><button type="submit" id="edit-submit" name="op" value="Search" '
#  'class="btn btn-primary form-submit icon-after"><span '
#  'class="sr-only">Search</span> <span class="glyphicon glyphicon-search" '
#  'aria-hidden="true"></span></button>\n'
#  '<input type="hidden" name="form_build_id" '
#  'value="form--tFG51hEMtr1UVLrUxYo9WX2ZLGV2nXUlxWPogeDFy4" />\n'
#  '<input type="hidden" name="form_id" value="cu_gcse_embed_search_form" />\n'
#  '</div></form>\n'
#  '</section>\n'
#  '  </div>\n'
#  '  </div>\n'
#  '    </div>\n'
#  '  </div>\n'
#  '\n'
#  '  <div class="row m-navbar-collapse collapse">\n'
#  '    <div id="navbar-mobile" class="navbar-mobile col-sm-12">\n'
#  '              <nav role="navigation">\n'
#  '                                            <div class="region '
#  'region-navigation">\n'
#  '    <section id="block-menu-block-1" class="block block-menu-block '
#  'clearfix">\n'
#  '\n'
#  '      \n'
#  '  <div class="menu-block-wrapper menu-block-1 menu-name-main-menu '
#  'parent-mlid-0 menu-level-1">\n'
#  '  <ul class="menu nav"><li class="first expanded menu-mlid-697 level-1 '
#  'dropdown"><a href="/admissions" title="Admissions" '
#  'class="level-1">Admissions</a><ul class="dropdown-menu dl-submenu"><li '
#  'class="first expanded menu-mlid-604 level-2 list-group"><a '
#  'href="/where-begin" title="Where to Begin" class="level-2">Where to '
#  'Begin</a><ul class="submenu dl-submenu"><li class="first leaf menu-mlid-773 '
#  'level-3"><a href="/deadlines-and-application-requirements" title="Deadlines '
#  '&amp; Requirements" class="level-3">Deadlines &amp; Requirements</a></li>\n'
#  '<li class="leaf has-children menu-mlid-628 level-3"><a '
#  'href="/cost-attendance" title="Cost of Attendance" class="level-3">Cost of '
#  'Attendance</a></li>\n'
#  '<li class="leaf menu-mlid-1356 level-3"><a href="/scholarships" '
#  'title="Scholarships at Columbia Journalism School" '
#  'class="level-3">Scholarships</a></li>\n'
#  '<li class="leaf menu-mlid-629 level-3"><a '
#  'href="/scholarships-and-financial-aid" title="Financial Aid" '
#  'class="level-3">Financial Aid</a></li>\n'
#  '<li class="leaf menu-mlid-615 level-3"><a '
#  'href="/frequently-asked-questions?tag=153" title="Frequently Asked '
#  'Questions" class="level-3">Frequently Asked Questions</a></li>\n'
#  '<li class="leaf menu-mlid-835 level-3"><a '
#  'href="https://apply.jrn.columbia.edu/register/stayconnected" title="Request '
#  'Info" class="level-3">Request Info</a></li>\n'
#  '<li class="leaf menu-mlid-836 level-3"><a href="/meet-us" title="Meet With '
#  'Us" class="level-3">Meet With Us</a></li>\n'
#  '<li class="leaf menu-mlid-837 level-3"><a '
#  'href="/contact-information?type=97" title="Contact Us" '
#  'class="level-3">Contact Us</a></li>\n'
#  '<li class="last leaf menu-mlid-834 level-3"><a '
#  'href="https://apply.jrn.columbia.edu/apply" class="level-3">Apply</a></li>\n'
#  '</ul></li>\n'
#  '<li class="last expanded menu-mlid-634 level-2 list-group"><a '
#  'href="/student-life" class="level-2">Student Life</a><ul class="submenu '
#  'dl-submenu"><li class="first leaf menu-mlid-635 level-3"><a '
#  'href="/new-student-information" class="level-3">New Student '
#  'Information</a></li>\n'
#  '<li class="leaf menu-mlid-636 level-3"><a href="/extracurricular-life" '
#  'class="level-3">Extracurricular Activities</a></li>\n'
#  '<li class="leaf menu-mlid-637 level-3"><a '
#  'href="/student-life#Policies__amp__Resources" class="level-3">School '
#  'Policies</a></li>\n'
#  '<li class="leaf menu-mlid-638 level-3"><a '
#  'href="/student-life#Important_Student_Dates" class="level-3">Important '
#  'Dates</a></li>\n'
#  '<li class="leaf menu-mlid-1240 level-3"><a href="/graduation" '
#  'class="level-3">Graduation</a></li>\n'
#  '<li class="leaf menu-mlid-1239 level-3"><a '
#  'href="/current-students-faculty-and-staff" class="level-3">For Current '
#  'Students</a></li>\n'
#  '<li class="last leaf menu-mlid-1400 level-3"><a '
#  'href="/diversity-equity-and-inclusion" title="Diversity, Equity and '
#  'Inclusion" class="level-3">Diversity, Equity and Inclusion</a></li>\n'
#  '</ul></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-692 level-1 dropdown"><a href="/programs" '
#  'title="Programs" class="level-1">Programs</a><ul class="dropdown-menu '
#  'dl-submenu"><li class="first expanded menu-mlid-838 level-2 list-group"><a '
#  'href="/programs#Areas_of_Study" title="Areas of Study" class="level-2">Areas '
#  'of Study</a><ul class="submenu dl-submenu"><li class="first leaf '
#  'menu-mlid-762 level-3"><a href="/arts-and-culture" title="Arts Journalism" '
#  'class="level-3">Arts</a></li>\n'
#  '<li class="leaf menu-mlid-761 level-3"><a href="/audio" '
#  'class="level-3">Audio</a></li>\n'
#  '<li class="leaf menu-mlid-759 level-3"><a href="/broadcast" '
#  'class="level-3">Broadcast</a></li>\n'
#  '<li class="leaf menu-mlid-839 level-3"><a href="/business" '
#  'class="level-3">Business</a></li>\n'
#  '<li class="leaf menu-mlid-755 level-3"><a href="/data" '
#  'class="level-3">Data</a></li>\n'
#  '<li class="leaf menu-mlid-756 level-3"><a href="/documentary" '
#  'class="level-3">Documentary</a></li>\n'
#  '<li class="leaf menu-mlid-764 level-3"><a href="/international" '
#  'class="level-3">International</a></li>\n'
#  '<li class="leaf menu-mlid-758 level-3"><a href="/investigative" '
#  'class="level-3">Investigative</a></li>\n'
#  '<li class="leaf menu-mlid-757 level-3"><a href="/multimedia" '
#  'class="level-3">Multimedia</a></li>\n'
#  '<li class="leaf menu-mlid-766 level-3"><a href="/politics" '
#  'class="level-3">Politics</a></li>\n'
#  '<li class="leaf menu-mlid-765 level-3"><a href="/science" '
#  'class="level-3">Science</a></li>\n'
#  '<li class="last leaf menu-mlid-763 level-3"><a href="/writing" '
#  'class="level-3">Writing</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-699 level-2 list-group"><a href="/ms-degree" '
#  'class="level-2">Master of Science</a><ul class="submenu dl-submenu"><li '
#  'class="first leaf menu-mlid-840 level-3"><a href="/student-work?type=69" '
#  'class="level-3">Student Work</a></li>\n'
#  '<li class="leaf menu-mlid-841 level-3"><a href="/ms-degree#Curriculum" '
#  'class="level-3">Curriculum</a></li>\n'
#  '<li class="leaf menu-mlid-843 level-3"><a '
#  'href="/programs#Compare_M_S___M_S__Data__amp__M_A_" class="level-3">Compare '
#  'M.S./M.S. Data/M.A.</a></li>\n'
#  '<li class="leaf menu-mlid-1062 level-3"><a href="/ms-part-time" '
#  'class="level-3">Part-time Program</a></li>\n'
#  '<li class="leaf menu-mlid-1058 level-3"><a '
#  'href="/ms-documentary-specialization" class="level-3">Documentary '
#  'Specialization</a></li>\n'
#  '<li class="leaf menu-mlid-1056 level-3"><a '
#  'href="/ms-investigative-specialization" class="level-3">Investigative '
#  'Specialization</a></li>\n'
#  '<li class="last leaf has-children menu-mlid-1066 level-3"><a href="/classes" '
#  'class="level-3">Class Descriptions</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-1241 level-2 list-group"><a '
#  'href="/ms-data-journalism" class="level-2">M.S. Data JRN</a><ul '
#  'class="submenu dl-submenu"><li class="first leaf menu-mlid-1243 level-3"><a '
#  'href="/student-work?type=76" class="level-3">Student Work</a></li>\n'
#  '<li class="leaf menu-mlid-1244 level-3"><a '
#  'href="/ms-data-journalism#Curriculum" class="level-3">Curriculum</a></li>\n'
#  '<li class="leaf menu-mlid-1242 level-3"><a '
#  'href="/programs#Compare_M_S_M_S___amp__M_A__" class="level-3">Compare '
#  'M.S./M.S.Data/M.A.</a></li>\n'
#  '<li class="last leaf menu-mlid-1245 level-3"><a href="/classes?subject=46" '
#  'class="level-3">Class Descriptions</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-844 level-2 list-group"><a href="/ma-degree" '
#  'class="level-2">Master of Arts</a><ul class="submenu dl-submenu"><li '
#  'class="first leaf menu-mlid-845 level-3"><a href="/student-work?type=70" '
#  'class="level-3">Student Work</a></li>\n'
#  '<li class="leaf menu-mlid-846 level-3"><a href="/ma-degree#Curriculum" '
#  'class="level-3">Curriculum</a></li>\n'
#  '<li class="leaf menu-mlid-848 level-3"><a '
#  'href="/programs#Compare_M_S___amp__M_A_" class="level-3">Compare '
#  'M.S./M.A.</a></li>\n'
#  '<li class="leaf menu-mlid-849 level-3"><a '
#  'href="/ma-arts-culture-concentration" class="level-3">Arts &amp; Culture '
#  'Concentration</a></li>\n'
#  '<li class="leaf menu-mlid-850 level-3"><a '
#  'href="/ma-business-economics-concentration" class="level-3">Business &amp; '
#  'Economics Concentration</a></li>\n'
#  '<li class="leaf menu-mlid-851 level-3"><a href="/ma-politics-concentration" '
#  'class="level-3">Politics Concentration</a></li>\n'
#  '<li class="last leaf menu-mlid-852 level-3"><a '
#  'href="/ma-science-concentration" class="level-3">Science '
#  'Concentration</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-700 level-2 list-group"><a '
#  'href="/dual-degree-programs" class="level-2">Dual Degrees</a><ul '
#  'class="submenu dl-submenu"><li class="first leaf has-children menu-mlid-853 '
#  'level-3"><a href="/journalism-computer-science" class="level-3">Journalism '
#  '&amp; Computer Science</a></li>\n'
#  '<li class="leaf menu-mlid-854 level-3"><a href="/dual-degree-programs" '
#  'class="level-3">Dual Degrees With Other Departments</a></li>\n'
#  '<li class="last leaf menu-mlid-855 level-3"><a '
#  'href="/international-programs" class="level-3">International Dual '
#  'Degrees</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-701 level-2 list-group"><a '
#  'href="/phd-communications" class="level-2">Ph.D.</a><ul class="submenu '
#  'dl-submenu"><li class="first leaf menu-mlid-1063 level-3"><a '
#  'href="/phd-student-work" class="level-3">Student Work</a></li>\n'
#  '<li class="leaf menu-mlid-1201 level-3"><a href="/phd-program-student-bios" '
#  'class="level-3">Student Bios</a></li>\n'
#  '<li class="leaf menu-mlid-1200 level-3"><a href="/phd-program-faculty" '
#  'class="level-3">Faculty</a></li>\n'
#  '<li class="leaf menu-mlid-799 level-3"><a href="/phd-requirements" '
#  'class="level-3">Requirements</a></li>\n'
#  '<li class="leaf menu-mlid-1251 level-3"><a href="/phd-class-descriptions" '
#  'class="level-3">Ph.D. Class Descriptions</a></li>\n'
#  '<li class="last leaf menu-mlid-1199 level-3"><a '
#  'href="/phd-communications#Financial_Aid" class="level-3">Financial '
#  'Aid</a></li>\n'
#  '</ul></li>\n'
#  '<li class="last expanded menu-mlid-881 level-2 list-group"><a '
#  'href="/other-programs" class="level-2">Other Programs</a><ul class="submenu '
#  'dl-submenu"><li class="first leaf has-children menu-mlid-814 level-3"><a '
#  'href="/kb" title="Knight-Bagehot Fellowship in Business and Economics '
#  'Journalism" class="level-3">Knight-Bagehot</a></li>\n'
#  '<li class="leaf has-children menu-mlid-858 level-3"><a '
#  'href="/spencer-education-fellowship" class="level-3">Spencer '
#  'Fellowship</a></li>\n'
#  '<li class="last leaf menu-mlid-1198 level-3"><a href="/cross-registration" '
#  'class="level-3">Cross Registration</a></li>\n'
#  '</ul></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-693 level-1 dropdown"><a href="/student-work" '
#  'class="level-1">Student Work</a><ul class="dropdown-menu dl-submenu"><li '
#  'class="first leaf menu-mlid-860 level-2"><a href="/student-work?type=72" '
#  'class="level-2">Arts</a></li>\n'
#  '<li class="leaf menu-mlid-861 level-2"><a href="/student-work?type=73" '
#  'class="level-2">Audio</a></li>\n'
#  '<li class="leaf menu-mlid-862 level-2"><a href="/student-work?type=74" '
#  'class="level-2">Broadcast</a></li>\n'
#  '<li class="leaf menu-mlid-863 level-2"><a href="/student-work?type=75" '
#  'class="level-2">Business</a></li>\n'
#  '<li class="leaf menu-mlid-864 level-2"><a href="/student-work?type=76" '
#  'class="level-2">Data</a></li>\n'
#  '<li class="leaf menu-mlid-865 level-2"><a href="/student-work?type=77" '
#  'class="level-2">Documentary</a></li>\n'
#  '<li class="leaf menu-mlid-866 level-2"><a href="/student-work?type=78" '
#  'class="level-2">International</a></li>\n'
#  '<li class="leaf menu-mlid-867 level-2"><a href="/student-work?type=79" '
#  'class="level-2">Investigative</a></li>\n'
#  '<li class="leaf menu-mlid-868 level-2"><a href="/student-work?type=80" '
#  'class="level-2">Multimedia</a></li>\n'
#  '<li class="leaf menu-mlid-869 level-2"><a href="/student-work?type=81" '
#  'class="level-2">Politics</a></li>\n'
#  '<li class="leaf menu-mlid-870 level-2"><a href="/student-work?type=82" '
#  'class="level-2">Science</a></li>\n'
#  '<li class="last leaf menu-mlid-871 level-2"><a href="/student-work?type=83" '
#  'class="level-2">Writing</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-694 level-1 dropdown"><a href="/careers" '
#  'class="level-1">Careers</a><ul class="dropdown-menu dl-submenu"><li '
#  'class="first leaf menu-mlid-878 level-2"><a '
#  'href="/careers#Career_Development" class="level-2">Career '
#  'Development</a></li>\n'
#  '<li class="leaf menu-mlid-684 level-2"><a href="/career-expo" '
#  'class="level-2">Career Expo</a></li>\n'
#  '<li class="leaf menu-mlid-683 level-2"><a href="/fellowships-internships" '
#  'class="level-2">Exclusive Opportunities</a></li>\n'
#  '<li class="leaf menu-mlid-1158 level-2"><a '
#  'href="/columbia-postgraduate-fellowships" class="level-2">Postgraduate '
#  'Fellowships</a></li>\n'
#  '<li class="leaf menu-mlid-685 level-2"><a href="/employers" '
#  'class="level-2">For Employers</a></li>\n'
#  '<li class="last leaf menu-mlid-1235 level-2"><a href="/career-development" '
#  'class="level-2">For Current Students</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-686 level-1 dropdown"><a href="/alumni" '
#  'class="level-1">Alumni</a><ul class="dropdown-menu dl-submenu"><li '
#  'class="first expanded menu-mlid-872 level-2 list-group"><a '
#  'href="/node/1377/" title="Alumni Weekend" class="level-2">Alumni '
#  'Weekend</a><ul class="submenu dl-submenu"><li class="first last leaf '
#  'menu-mlid-1411 level-3"><a href="/past-alumni-weekends" class="level-3">Past '
#  'Alumni Weekends</a></li>\n'
#  '</ul></li>\n'
#  '<li class="leaf menu-mlid-874 level-2"><a href="/alumni#Alumni_Resources" '
#  'class="level-2">Alumni Resources</a></li>\n'
#  '<li class="last leaf menu-mlid-875 level-2"><a '
#  'href="/alumni#Career_Development" class="level-2">Career '
#  'Development</a></li>\n'
#  '</ul></li>\n'
#  '<li class="leaf menu-mlid-1413 level-1"><a href="/centers" '
#  'class="level-1">Centers</a></li>\n'
#  '<li class="expanded menu-mlid-696 level-1 dropdown"><a '
#  'href="/professional-development" class="level-1">Professional '
#  'Development</a><ul class="dropdown-menu dl-submenu"><li class="first leaf '
#  'menu-mlid-806 level-2"><a '
#  'href="/professional-development#Investigative_Reporting" '
#  'class="level-2">Investigative Reporting</a></li>\n'
#  '<li class="leaf menu-mlid-877 level-2"><a '
#  'href="/professional-development#Data" class="level-2">Data</a></li>\n'
#  '<li class="leaf menu-mlid-805 level-2"><a '
#  'href="/professional-development#Video" title="Video" '
#  'class="level-2">Video</a></li>\n'
#  '<li class="leaf menu-mlid-1361 level-2"><a href="/latin-america" '
#  'title="Columbia Journalism School in Latin America: Our Initiatives" '
#  'class="level-2">CJS in Latin America</a></li>\n'
#  '<li class="leaf menu-mlid-680 level-2"><a '
#  'href="/sulzberger-executive-leadership-program" title="Sulzberger Executive '
#  'Leadership Program" class="level-2">Sulzberger Leadership Program</a></li>\n'
#  '<li class="leaf menu-mlid-1371 level-2"><a href="/audio-boot-camp" '
#  'class="level-2">Audio Boot Camp</a></li>\n'
#  '<li class="last leaf menu-mlid-1379 level-2"><a href="/cpc" title="Columbia '
#  'Publishing Course" class="level-2">Columbia Publishing Course</a></li>\n'
#  '</ul></li>\n'
#  '<li class="last expanded active-trail menu-mlid-552 active level-1 '
#  'dropdown"><a href="/about" class="active-trail level-1">About Us</a><ul '
#  'class="dropdown-menu dl-submenu"><li class="first leaf active-trail active '
#  'menu-mlid-822 active level-2 active"><a href="/faculty?expertise=158" '
#  'class="active-trail level-2 active">Faculty</a></li>\n'
#  '<li class="leaf menu-mlid-880 level-2"><a href="/news" '
#  'class="level-2">News</a></li>\n'
#  '<li class="leaf menu-mlid-827 level-2"><a href="/events?tid=67" '
#  'class="level-2">Events</a></li>\n'
#  '<li class="collapsed menu-mlid-826 level-2"><a href="/prizes" '
#  'class="level-2">Prizes</a></li>\n'
#  '<li class="leaf menu-mlid-1358 level-2"><a href="/educational-experience" '
#  'title="Centers and institutes at Columbia Journalism School" '
#  'class="level-2">The Educational Experience</a></li>\n'
#  '<li class="leaf menu-mlid-689 level-2"><a href="/event-rentals" '
#  'class="level-2">Rent Event &amp; Studio Space</a></li>\n'
#  '<li class="leaf menu-mlid-1065 level-2"><a '
#  'href="/current-students-faculty-and-staff" target="_blank" '
#  'class="level-2">Students, Faculty &amp; Staff</a></li>\n'
#  '<li class="last leaf menu-mlid-879 level-2"><a href="/support-school" '
#  'class="level-2">Support the School</a></li>\n'
#  '</ul></li>\n'
#  '</ul></div>\n'
#  '\n'
#  '</section>\n'
#  '  </div>\n'
#  '                  </nav>\n'
#  '          </div>\n'
#  '  </div>\n'
#  '\n'
#  '  <div class="row hidden-sm hidden-md hidden-xs">\n'
#  '    <div id="navbar" class="navbar col-md-12 navbar-default">\n'
#  '                <nav role="navigation">\n'
#  '                                                    <div class="region '
#  'region-navigation">\n'
#  '      <div class="region region-navigation">\n'
#  '    <section id="block-menu-block-1" class="block block-menu-block '
#  'clearfix">\n'
#  '\n'
#  '      \n'
#  '  <div class="menu-block-wrapper menu-block-1 menu-name-main-menu '
#  'parent-mlid-0 menu-level-1">\n'
#  '  <ul class="menu nav"><li class="first expanded menu-mlid-697 level-1 '
#  'dropdown"><a href="/admissions" title="Admissions" '
#  'class="level-1">Admissions</a><ul class="dropdown-menu dl-submenu"><li '
#  'class="first expanded menu-mlid-604 level-2 list-group"><a '
#  'href="/where-begin" title="Where to Begin" class="level-2">Where to '
#  'Begin</a><ul class="submenu dl-submenu"><li class="first leaf menu-mlid-773 '
#  'level-3"><a href="/deadlines-and-application-requirements" title="Deadlines '
#  '&amp; Requirements" class="level-3">Deadlines &amp; Requirements</a></li>\n'
#  '<li class="leaf has-children menu-mlid-628 level-3"><a '
#  'href="/cost-attendance" title="Cost of Attendance" class="level-3">Cost of '
#  'Attendance</a></li>\n'
#  '<li class="leaf menu-mlid-1356 level-3"><a href="/scholarships" '
#  'title="Scholarships at Columbia Journalism School" '
#  'class="level-3">Scholarships</a></li>\n'
#  '<li class="leaf menu-mlid-629 level-3"><a '
#  'href="/scholarships-and-financial-aid" title="Financial Aid" '
#  'class="level-3">Financial Aid</a></li>\n'
#  '<li class="leaf menu-mlid-615 level-3"><a '
#  'href="/frequently-asked-questions?tag=153" title="Frequently Asked '
#  'Questions" class="level-3">Frequently Asked Questions</a></li>\n'
#  '<li class="leaf menu-mlid-835 level-3"><a '
#  'href="https://apply.jrn.columbia.edu/register/stayconnected" title="Request '
#  'Info" class="level-3">Request Info</a></li>\n'
#  '<li class="leaf menu-mlid-836 level-3"><a href="/meet-us" title="Meet With '
#  'Us" class="level-3">Meet With Us</a></li>\n'
#  '<li class="leaf menu-mlid-837 level-3"><a '
#  'href="/contact-information?type=97" title="Contact Us" '
#  'class="level-3">Contact Us</a></li>\n'
#  '<li class="last leaf menu-mlid-834 level-3"><a '
#  'href="https://apply.jrn.columbia.edu/apply" class="level-3">Apply</a></li>\n'
#  '</ul></li>\n'
#  '<li class="last expanded menu-mlid-634 level-2 list-group"><a '
#  'href="/student-life" class="level-2">Student Life</a><ul class="submenu '
#  'dl-submenu"><li class="first leaf menu-mlid-635 level-3"><a '
#  'href="/new-student-information" class="level-3">New Student '
#  'Information</a></li>\n'
#  '<li class="leaf menu-mlid-636 level-3"><a href="/extracurricular-life" '
#  'class="level-3">Extracurricular Activities</a></li>\n'
#  '<li class="leaf menu-mlid-637 level-3"><a '
#  'href="/student-life#Policies__amp__Resources" class="level-3">School '
#  'Policies</a></li>\n'
#  '<li class="leaf menu-mlid-638 level-3"><a '
#  'href="/student-life#Important_Student_Dates" class="level-3">Important '
#  'Dates</a></li>\n'
#  '<li class="leaf menu-mlid-1240 level-3"><a href="/graduation" '
#  'class="level-3">Graduation</a></li>\n'
#  '<li class="leaf menu-mlid-1239 level-3"><a '
#  'href="/current-students-faculty-and-staff" class="level-3">For Current '
#  'Students</a></li>\n'
#  '<li class="last leaf menu-mlid-1400 level-3"><a '
#  'href="/diversity-equity-and-inclusion" title="Diversity, Equity and '
#  'Inclusion" class="level-3">Diversity, Equity and Inclusion</a></li>\n'
#  '</ul></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-692 level-1 dropdown"><a href="/programs" '
#  'title="Programs" class="level-1">Programs</a><ul class="dropdown-menu '
#  'dl-submenu"><li class="first expanded menu-mlid-838 level-2 list-group"><a '
#  'href="/programs#Areas_of_Study" title="Areas of Study" class="level-2">Areas '
#  'of Study</a><ul class="submenu dl-submenu"><li class="first leaf '
#  'menu-mlid-762 level-3"><a href="/arts-and-culture" title="Arts Journalism" '
#  'class="level-3">Arts</a></li>\n'
#  '<li class="leaf menu-mlid-761 level-3"><a href="/audio" '
#  'class="level-3">Audio</a></li>\n'
#  '<li class="leaf menu-mlid-759 level-3"><a href="/broadcast" '
#  'class="level-3">Broadcast</a></li>\n'
#  '<li class="leaf menu-mlid-839 level-3"><a href="/business" '
#  'class="level-3">Business</a></li>\n'
#  '<li class="leaf menu-mlid-755 level-3"><a href="/data" '
#  'class="level-3">Data</a></li>\n'
#  '<li class="leaf menu-mlid-756 level-3"><a href="/documentary" '
#  'class="level-3">Documentary</a></li>\n'
#  '<li class="leaf menu-mlid-764 level-3"><a href="/international" '
#  'class="level-3">International</a></li>\n'
#  '<li class="leaf menu-mlid-758 level-3"><a href="/investigative" '
#  'class="level-3">Investigative</a></li>\n'
#  '<li class="leaf menu-mlid-757 level-3"><a href="/multimedia" '
#  'class="level-3">Multimedia</a></li>\n'
#  '<li class="leaf menu-mlid-766 level-3"><a href="/politics" '
#  'class="level-3">Politics</a></li>\n'
#  '<li class="leaf menu-mlid-765 level-3"><a href="/science" '
#  'class="level-3">Science</a></li>\n'
#  '<li class="last leaf menu-mlid-763 level-3"><a href="/writing" '
#  'class="level-3">Writing</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-699 level-2 list-group"><a href="/ms-degree" '
#  'class="level-2">Master of Science</a><ul class="submenu dl-submenu"><li '
#  'class="first leaf menu-mlid-840 level-3"><a href="/student-work?type=69" '
#  'class="level-3">Student Work</a></li>\n'
#  '<li class="leaf menu-mlid-841 level-3"><a href="/ms-degree#Curriculum" '
#  'class="level-3">Curriculum</a></li>\n'
#  '<li class="leaf menu-mlid-843 level-3"><a '
#  'href="/programs#Compare_M_S___M_S__Data__amp__M_A_" class="level-3">Compare '
#  'M.S./M.S. Data/M.A.</a></li>\n'
#  '<li class="leaf menu-mlid-1062 level-3"><a href="/ms-part-time" '
#  'class="level-3">Part-time Program</a></li>\n'
#  '<li class="leaf menu-mlid-1058 level-3"><a '
#  'href="/ms-documentary-specialization" class="level-3">Documentary '
#  'Specialization</a></li>\n'
#  '<li class="leaf menu-mlid-1056 level-3"><a '
#  'href="/ms-investigative-specialization" class="level-3">Investigative '
#  'Specialization</a></li>\n'
#  '<li class="last leaf has-children menu-mlid-1066 level-3"><a href="/classes" '
#  'class="level-3">Class Descriptions</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-1241 level-2 list-group"><a '
#  'href="/ms-data-journalism" class="level-2">M.S. Data JRN</a><ul '
#  'class="submenu dl-submenu"><li class="first leaf menu-mlid-1243 level-3"><a '
#  'href="/student-work?type=76" class="level-3">Student Work</a></li>\n'
#  '<li class="leaf menu-mlid-1244 level-3"><a '
#  'href="/ms-data-journalism#Curriculum" class="level-3">Curriculum</a></li>\n'
#  '<li class="leaf menu-mlid-1242 level-3"><a '
#  'href="/programs#Compare_M_S_M_S___amp__M_A__" class="level-3">Compare '
#  'M.S./M.S.Data/M.A.</a></li>\n'
#  '<li class="last leaf menu-mlid-1245 level-3"><a href="/classes?subject=46" '
#  'class="level-3">Class Descriptions</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-844 level-2 list-group"><a href="/ma-degree" '
#  'class="level-2">Master of Arts</a><ul class="submenu dl-submenu"><li '
#  'class="first leaf menu-mlid-845 level-3"><a href="/student-work?type=70" '
#  'class="level-3">Student Work</a></li>\n'
#  '<li class="leaf menu-mlid-846 level-3"><a href="/ma-degree#Curriculum" '
#  'class="level-3">Curriculum</a></li>\n'
#  '<li class="leaf menu-mlid-848 level-3"><a '
#  'href="/programs#Compare_M_S___amp__M_A_" class="level-3">Compare '
#  'M.S./M.A.</a></li>\n'
#  '<li class="leaf menu-mlid-849 level-3"><a '
#  'href="/ma-arts-culture-concentration" class="level-3">Arts &amp; Culture '
#  'Concentration</a></li>\n'
#  '<li class="leaf menu-mlid-850 level-3"><a '
#  'href="/ma-business-economics-concentration" class="level-3">Business &amp; '
#  'Economics Concentration</a></li>\n'
#  '<li class="leaf menu-mlid-851 level-3"><a href="/ma-politics-concentration" '
#  'class="level-3">Politics Concentration</a></li>\n'
#  '<li class="last leaf menu-mlid-852 level-3"><a '
#  'href="/ma-science-concentration" class="level-3">Science '
#  'Concentration</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-700 level-2 list-group"><a '
#  'href="/dual-degree-programs" class="level-2">Dual Degrees</a><ul '
#  'class="submenu dl-submenu"><li class="first leaf has-children menu-mlid-853 '
#  'level-3"><a href="/journalism-computer-science" class="level-3">Journalism '
#  '&amp; Computer Science</a></li>\n'
#  '<li class="leaf menu-mlid-854 level-3"><a href="/dual-degree-programs" '
#  'class="level-3">Dual Degrees With Other Departments</a></li>\n'
#  '<li class="last leaf menu-mlid-855 level-3"><a '
#  'href="/international-programs" class="level-3">International Dual '
#  'Degrees</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-701 level-2 list-group"><a '
#  'href="/phd-communications" class="level-2">Ph.D.</a><ul class="submenu '
#  'dl-submenu"><li class="first leaf menu-mlid-1063 level-3"><a '
#  'href="/phd-student-work" class="level-3">Student Work</a></li>\n'
#  '<li class="leaf menu-mlid-1201 level-3"><a href="/phd-program-student-bios" '
#  'class="level-3">Student Bios</a></li>\n'
#  '<li class="leaf menu-mlid-1200 level-3"><a href="/phd-program-faculty" '
#  'class="level-3">Faculty</a></li>\n'
#  '<li class="leaf menu-mlid-799 level-3"><a href="/phd-requirements" '
#  'class="level-3">Requirements</a></li>\n'
#  '<li class="leaf menu-mlid-1251 level-3"><a href="/phd-class-descriptions" '
#  'class="level-3">Ph.D. Class Descriptions</a></li>\n'
#  '<li class="last leaf menu-mlid-1199 level-3"><a '
#  'href="/phd-communications#Financial_Aid" class="level-3">Financial '
#  'Aid</a></li>\n'
#  '</ul></li>\n'
#  '<li class="last expanded menu-mlid-881 level-2 list-group"><a '
#  'href="/other-programs" class="level-2">Other Programs</a><ul class="submenu '
#  'dl-submenu"><li class="first leaf has-children menu-mlid-814 level-3"><a '
#  'href="/kb" title="Knight-Bagehot Fellowship in Business and Economics '
#  'Journalism" class="level-3">Knight-Bagehot</a></li>\n'
#  '<li class="leaf has-children menu-mlid-858 level-3"><a '
#  'href="/spencer-education-fellowship" class="level-3">Spencer '
#  'Fellowship</a></li>\n'
#  '<li class="last leaf menu-mlid-1198 level-3"><a href="/cross-registration" '
#  'class="level-3">Cross Registration</a></li>\n'
#  '</ul></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-693 level-1 dropdown"><a href="/student-work" '
#  'class="level-1">Student Work</a><ul class="dropdown-menu dl-submenu"><li '
#  'class="first leaf menu-mlid-860 level-2"><a href="/student-work?type=72" '
#  'class="level-2">Arts</a></li>\n'
#  '<li class="leaf menu-mlid-861 level-2"><a href="/student-work?type=73" '
#  'class="level-2">Audio</a></li>\n'
#  '<li class="leaf menu-mlid-862 level-2"><a href="/student-work?type=74" '
#  'class="level-2">Broadcast</a></li>\n'
#  '<li class="leaf menu-mlid-863 level-2"><a href="/student-work?type=75" '
#  'class="level-2">Business</a></li>\n'
#  '<li class="leaf menu-mlid-864 level-2"><a href="/student-work?type=76" '
#  'class="level-2">Data</a></li>\n'
#  '<li class="leaf menu-mlid-865 level-2"><a href="/student-work?type=77" '
#  'class="level-2">Documentary</a></li>\n'
#  '<li class="leaf menu-mlid-866 level-2"><a href="/student-work?type=78" '
#  'class="level-2">International</a></li>\n'
#  '<li class="leaf menu-mlid-867 level-2"><a href="/student-work?type=79" '
#  'class="level-2">Investigative</a></li>\n'
#  '<li class="leaf menu-mlid-868 level-2"><a href="/student-work?type=80" '
#  'class="level-2">Multimedia</a></li>\n'
#  '<li class="leaf menu-mlid-869 level-2"><a href="/student-work?type=81" '
#  'class="level-2">Politics</a></li>\n'
#  '<li class="leaf menu-mlid-870 level-2"><a href="/student-work?type=82" '
#  'class="level-2">Science</a></li>\n'
#  '<li class="last leaf menu-mlid-871 level-2"><a href="/student-work?type=83" '
#  'class="level-2">Writing</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-694 level-1 dropdown"><a href="/careers" '
#  'class="level-1">Careers</a><ul class="dropdown-menu dl-submenu"><li '
#  'class="first leaf menu-mlid-878 level-2"><a '
#  'href="/careers#Career_Development" class="level-2">Career '
#  'Development</a></li>\n'
#  '<li class="leaf menu-mlid-684 level-2"><a href="/career-expo" '
#  'class="level-2">Career Expo</a></li>\n'
#  '<li class="leaf menu-mlid-683 level-2"><a href="/fellowships-internships" '
#  'class="level-2">Exclusive Opportunities</a></li>\n'
#  '<li class="leaf menu-mlid-1158 level-2"><a '
#  'href="/columbia-postgraduate-fellowships" class="level-2">Postgraduate '
#  'Fellowships</a></li>\n'
#  '<li class="leaf menu-mlid-685 level-2"><a href="/employers" '
#  'class="level-2">For Employers</a></li>\n'
#  '<li class="last leaf menu-mlid-1235 level-2"><a href="/career-development" '
#  'class="level-2">For Current Students</a></li>\n'
#  '</ul></li>\n'
#  '<li class="expanded menu-mlid-686 level-1 dropdown"><a href="/alumni" '
#  'class="level-1">Alumni</a><ul class="dropdown-menu dl-submenu"><li '
#  'class="first expanded menu-mlid-872 level-2 list-group"><a '
#  'href="/node/1377/" title="Alumni Weekend" class="level-2">Alumni '
#  'Weekend</a><ul class="submenu dl-submenu"><li class="first last leaf '
#  'menu-mlid-1411 level-3"><a href="/past-alumni-weekends" class="level-3">Past '
#  'Alumni Weekends</a></li>\n'
#  '</ul></li>\n'
#  '<li class="leaf menu-mlid-874 level-2"><a href="/alumni#Alumni_Resources" '
#  'class="level-2">Alumni Resources</a></li>\n'
#  '<li class="last leaf menu-mlid-875 level-2"><a '
#  'href="/alumni#Career_Development" class="level-2">Career '
#  'Development</a></li>\n'
#  '</ul></li>\n'
#  '<li class="leaf menu-mlid-1413 level-1"><a href="/centers" '
#  'class="level-1">Centers</a></li>\n'
#  '<li class="expanded menu-mlid-696 level-1 dropdown"><a '
#  'href="/professional-development" class="level-1">Professional '
#  'Development</a><ul class="dropdown-menu dl-submenu"><li class="first leaf '
#  'menu-mlid-806 level-2"><a '
#  'href="/professional-development#Investigative_Reporting" '
#  'class="level-2">Investigative Reporting</a></li>\n'
#  '<li class="leaf menu-mlid-877 level-2"><a '
#  'href="/professional-development#Data" class="level-2">Data</a></li>\n'
#  '<li class="leaf menu-mlid-805 level-2"><a '
#  'href="/professional-development#Video" title="Video" '
#  'class="level-2">Video</a></li>\n'
#  '<li class="leaf menu-mlid-1361 level-2"><a href="/latin-america" '
#  'title="Columbia Journalism School in Latin America: Our Initiatives" '
#  'class="level-2">CJS in Latin America</a></li>\n'
#  '<li class="leaf menu-mlid-680 level-2"><a '
#  'href="/sulzberger-executive-leadership-program" title="Sulzberger Executive '
#  'Leadership Program" class="level-2">Sulzberger Leadership Program</a></li>\n'
#  '<li class="leaf menu-mlid-1371 level-2"><a href="/audio-boot-camp" '
#  'class="level-2">Audio Boot Camp</a></li>\n'
#  '<li class="last leaf menu-mlid-1379 level-2"><a href="/cpc" title="Columbia '
#  'Publishing Course" class="level-2">Columbia Publishing Course</a></li>\n'
#  '</ul></li>\n'
#  '<li class="last expanded active-trail menu-mlid-552 active level-1 '
#  'dropdown"><a href="/about" class="active-trail level-1">About Us</a><ul '
#  'class="dropdown-menu dl-submenu"><li class="first leaf active-trail active '
#  'menu-mlid-822 active level-2 active"><a href="/faculty?expertise=158" '
#  'class="active-trail level-2 active">Faculty</a></li>\n'
#  '<li class="leaf menu-mlid-880 level-2"><a href="/news" '
#  'class="level-2">News</a></li>\n'
#  '<li class="leaf menu-mlid-827 level-2"><a href="/events?tid=67" '
#  'class="level-2">Events</a></li>\n'
#  '<li class="collapsed menu-mlid-826 level-2"><a href="/prizes" '
#  'class="level-2">Prizes</a></li>\n'
#  '<li class="leaf menu-mlid-1358 level-2"><a href="/educational-experience" '
#  'title="Centers and institutes at Columbia Journalism School" '
#  'class="level-2">The Educational Experience</a></li>\n'
#  '<li class="leaf menu-mlid-689 level-2"><a href="/event-rentals" '
#  'class="level-2">Rent Event &amp; Studio Space</a></li>\n'
#  '<li class="leaf menu-mlid-1065 level-2"><a '
#  'href="/current-students-faculty-and-staff" target="_blank" '
#  'class="level-2">Students, Faculty &amp; Staff</a></li>\n'
#  '<li class="last leaf menu-mlid-879 level-2"><a href="/support-school" '
#  'class="level-2">Support the School</a></li>\n'
#  '</ul></li>\n'
#  '</ul></div>\n'
#  '\n'
#  '</section>\n'
#  '  </div>\n'
#  '  </div>\n'
#  '                      </nav>\n'
#  '          </div>\n'
#  '  </div>\n'
#  '\n'
#  '</header>\n'
#  '\n'
#  '<div class="main-container container">\n'
#  '\n'
#  '  <div class="row">\n'
#  '\n'
#  '    <div class="page-top col-sm-12">\n'
#  '            \n'
#  '      <ol class="breadcrumb"><li><a href="/">Home</a></li>\n'
#  '<li><a href="/about">About Us</a></li>\n'
#  '<li class="active">Faculty</li>\n'
#  '</ol>\n'
#  '                    \n'
#  '                                                                  </div>\n'
#  '  </div>\n'
#  '\n'
#  '  <div class="row">\n'
#  '    <section class="col-sm-12">\n'
#  '            <a id="main-content"></a>\n'
#  '                    <h1 class="page-header">Faculty</h1>\n'
#  '            \n'
# ...
#  'node-teaser teaser faculty-bio">\n'
#  '    <div class="faculty-photo">\n'
#  '      <a href="/faculty/denise-ajiri"><img class="img-responsive" '
#  'src="https://journalism.columbia.edu/files/soj/styles/faculty_photo/public/content/image/2022/31/f-88-6-13176708_01wgebpz_denise.jpg?itok=k-ND0dPI" '
#  'width="269" height="269" alt="" /></a>    </div>\n'
#  '    <h2 class="title regular"><a href="/faculty/denise-ajiri" '
#  'class="about-link">Denise Ajiri</a></h2>\n'
#  '        <div class="sub-title"><p>Adjunct Assistant Professor</p>\n'
#  '</div>\n'
#  '      </article>\n'
#  '\n'
#  '</span>  </div>  </div>\n'
#  '  <div class="views-row views-row-2 views-row-even col-sm-3">\n'
#  '      \n'
#  '  <div class="views-field views-field-edit-node">        <span '
#  'class="field-content"></span>  </div>  \n'
#  '  <div class="views-field views-field-rendered-entity">        <span '
#  'class="field-content">  <article id="node-1156" class="node node-faculty-bio '
#  'node-teaser teaser faculty-bio">\n'
#  '    <div class="faculty-photo">\n'
#  '      <a href="/faculty/andrea-fuller"><img class="img-responsive" '
#  'src="https://journalism.columbia.edu/files/soj/styles/faculty_photo/public/content/image/2019/04/andrea-fuller.jpg?itok=o-b7JFxn" '
#  'width="269" height="269" alt="" /></a>    </div>\n'
#  '    <h2 class="title regular"><a href="/faculty/andrea-fuller" '
#  'class="about-link">Andrea Fuller</a></h2>\n'
#  '        <div class="sub-title"><p>Adjunct Faculty</p>\n'
#  '</div>\n'
#  '      </article>\n'
#  '\n'
#  '</span>  </div>  </div>\n'
#  '  <div class="views-row views-row-3 views-row-odd col-sm-3">\n'
#  '      \n'
#  '  <div class="views-field views-field-edit-node">        <span '
#  'class="field-content"></span>  </div>  \n'
#  '  <div class="views-field views-field-rendered-entity">        <span '
#  'class="field-content">  <article id="node-964" class="node node-faculty-bio '
#  'node-teaser teaser faculty-bio">\n'
#  '    <div class="faculty-photo">\n'
#  '      <a href="/faculty/robert-gebeloff"><img class="img-responsive" '
#  'src="https://journalism.columbia.edu/files/soj/styles/faculty_photo/public/content/image/2018/08/gebeloff_mug.jpg?itok=xobEqTnF" '
#  'width="269" height="269" alt="" /></a>    </div>\n'
#  '    <h2 class="title regular"><a href="/faculty/robert-gebeloff" '
#  'class="about-link">Robert Gebeloff</a></h2>\n'
#  '        <div class="sub-title"><p>Adjunct Faculty</p>\n'
#  '</div>\n'
#  '      </article>\n'
#  '\n'
#  '</span>  </div>  </div>\n'
#  '  <div class="views-row views-row-4 views-row-even col-sm-3">\n'
#  '      \n'
#  '  <div class="views-field views-field-edit-node">        <span '
#  'class="field-content"></span>  </div>  \n'
#  '  <div class="views-field views-field-rendered-entity">        <span '
#  'class="field-content">  <article id="node-329" class="node node-faculty-bio '
#  'node-teaser teaser faculty-bio">\n'
#  '    <div class="faculty-photo">\n'
#  '      <a href="/faculty/mark-hansen"><img class="img-responsive" '
#  'src="https://journalism.columbia.edu/files/soj/styles/faculty_photo/public/content/image/2019/13/unnamed.jpg?itok=2XuOucM3" '
#  'width="269" height="269" alt="" /></a>    </div>\n'
#  '    <h2 class="title regular"><a href="/faculty/mark-hansen" '
#  'class="about-link">Mark Hansen</a></h2>\n'
#  '        <div class="sub-title"><p>David and Helen Gurley Brown Professor of '
#  'Journalism and Innovation; Director, David and Helen Gurley Brown Institute '
#  'of Media Innovation</p>\n'
#  '</div>\n'
#  '      </article>\n'
#  '\n'
#  '</span>  </div>  </div>\n'
#  '  <div class="views-row views-row-5 views-row-odd col-sm-3">\n'
#  '      \n'
#  '  <div class="views-field views-field-edit-node">        <span '
#  'class="field-content"></span>  </div>  \n'
#  '  <div class="views-field views-field-rendered-entity">        <span '
#  'class="field-content">  <article id="node-987" class="node node-faculty-bio '
#  'node-teaser teaser faculty-bio">\n'
#  '    <div class="faculty-photo">\n'
#  '      <a href="/faculty/tom-meagher"><img class="img-responsive" '
#  'src="https://journalism.columbia.edu/files/soj/styles/faculty_photo/public/content/image/2018/10/meagher_headshot.jpg?itok=_Z-lIZ0K" '
#  'width="269" height="269" alt="" /></a>    </div>\n'
#  '    <h2 class="title regular"><a href="/faculty/tom-meagher" '
#  'class="about-link">Tom  Meagher</a></h2>\n'
#  '        <div class="sub-title"><p>Adjunct Faculty</p>\n'
#  '</div>\n'
#  '      </article>\n'
#  '\n'
#  '</span>  </div>  </div>\n'
#  '  <div class="views-row views-row-6 views-row-even col-sm-3">\n'
#  '      \n'
#  '  <div class="views-field views-field-edit-node">        <span '
#  'class="field-content"></span>  </div>  \n'
#  '  <div class="views-field views-field-rendered-entity">        <span '
#  'class="field-content">  <article id="node-1556" class="node node-faculty-bio '
#  'node-teaser teaser faculty-bio">\n'
#  '    <div class="faculty-photo">\n'
#  '      <a href="/faculty/dhrumil-mehta"><img class="img-responsive" '
#  'src="https://journalism.columbia.edu/files/soj/styles/faculty_photo/public/content/image/2021/48/dhrumil-mehta.jpg?itok=uy15UL2s" '
#  'width="269" height="269" alt="" /></a>    </div>\n'
#  '    <h2 class="title regular"><a href="/faculty/dhrumil-mehta" '
#  'class="about-link">Dhrumil Mehta</a></h2>\n'
#  '        <div class="sub-title"><p>Associate Professor in Data Journalism; '
#  'Deputy Director of the Tow Center for Digital Journalism</p>\n'
#  '</div>\n'
#  '      </article>\n'
#  '\n'
#  '</span>  </div>  </div>\n'
#  '  <div class="views-row views-row-7 views-row-odd col-sm-3">\n'
#  '      \n'
#  '  <div class="views-field views-field-edit-node">        <span '
#  'class="field-content"></span>  </div>  \n'
#  '  <div class="views-field views-field-rendered-entity">        <span '
#  'class="field-content">  <article id="node-1525" class="node node-faculty-bio '
#  'node-teaser teaser faculty-bio">\n'
#  '    <div class="faculty-photo">\n'
#  '      <a href="/faculty/matt-rocheleau"><img class="img-responsive" '
#  'src="https://journalism.columbia.edu/files/soj/styles/faculty_photo/public/content/image/2021/33/matt-rocheleau.jpg?itok=Jva3rKfB" '
#  'width="269" height="269" alt="" /></a>    </div>\n'
#  '    <h2 class="title regular"><a href="/faculty/matt-rocheleau" '
#  'class="about-link">Matt Rocheleau</a></h2>\n'
#  '        <div class="sub-title"><p>Adjunct Faculty</p>\n'
#  '</div>\n'
#  '      </article>\n'
#  '\n'
#  '</span>  </div>  </div>\n'
#  '  <div class="views-row views-row-8 views-row-even views-row-last '
#  'col-sm-3">\n'
#  '      \n'
#  '  <div class="views-field views-field-edit-node">        <span '
#  'class="field-content"></span>  </div>  \n'
#  '  <div class="views-field views-field-rendered-entity">        <span '
#  'class="field-content">  <article id="node-338" class="node node-faculty-bio '
#  'node-teaser teaser faculty-bio">\n'
#  '    <div class="faculty-photo">\n'
#  '      <a href="/faculty/giannina-segnini"><img class="img-responsive" '
#  'src="https://journalism.columbia.edu/files/soj/styles/faculty_photo/public/content/image/2016/21/giannina_segnini.jpg?itok=IOEYXzCH" '
#  'width="269" height="269" alt="" /></a>    </div>\n'
#  '    <h2 class="title regular"><a href="/faculty/giannina-segnini" '
#  'class="about-link">Giannina Segnini</a></h2>\n'
#  '        <div class="sub-title"><p>John S. and James L. Knight Professor of '
#  'Professional Practice in Data Journalism</p>\n'
#  '</div>\n'
#  '      </article>\n'
#  '\n'
#  '</span>  </div>  </div>\n'
#  '    </div>\n'
#  '  \n'
#  '  \n'
#  '  \n'
#  '  \n'
#  '  \n'
#  '  \n'
#  '</div>\n'
#  '</section>\n'
#  '  </div>\n'
#  '    </section>\n'
#  '\n'
#  '  </div>\n'
#  '</div>\n'
#  '  <footer class="footer container">\n'
#  '    \n'
#  '<div class="back-top"><a href="#main-header">TOP <i class="fa '
#  'fa-arrow-up"></i></a></div>\n'
#  '<div class="region region-footer">\n'
#  '\n'
#  '  <div class="row">\n'
#  '    <div class="col-md-10">\n'
#  '      <div class="footer-main-nav hidden-xs hidden-sm menu-block">\n'
#  '        <ul class="menu nav"><li class="first leaf"><a '
#  'href="/admissions">Admissions</a></li>\n'
#  '<li class="leaf"><a href="/programs">Programs</a></li>\n'
#  '<li class="leaf"><a href="/student-work">Student Work</a></li>\n'
#  '<li class="leaf"><a href="/careers">Careers</a></li>\n'
#  '<li class="leaf"><a href="/alumni">Alumni</a></li>\n'
#  '<li class="leaf"><a href="/professional-development">Professional '
#  'Development</a></li>\n'
#  '<li class="last leaf"><a href="/contact-information">Contact Us</a></li>\n'
#  '</ul>      </div>\n'
#  '      <div class="footer-secondary-nav menu-block">\n'
#  '        <ul class="menu nav"><li class="first leaf active-trail active '
#  'active"><a href="/faculty?expertise=158" class="active-trail '
#  'active">Faculty</a></li>\n'
#  '<li class="leaf"><a href="/news">News</a></li>\n'
#  '<li class="leaf"><a href="/events?tid=67">Events</a></li>\n'
#  '<li class="last leaf"><a href="/prizes">Prizes</a></li>\n'
#  '</ul>      </div>\n'
#  '      <div class="footer-social-nav mobile visible-xs menu-block">\n'
#  '        <ul class="menu nav"><li class="first leaf"><a '
#  'href="https://www.facebook.com/columbiajournalism" class="fa '
#  'fa-facebook">Facebook</a></li>\n'
#  '<li class="leaf"><a href="https://twitter.com/columbiajourn" class="fa '
#  'fa-twitter">Twitter</a></li>\n'
#  '<li class="leaf"><a href="https://www.instagram.com/columbiajournalism/" '
#  'class="fa fa-instagram">Instagram</a></li>\n'
#  '<li class="leaf"><a href="https://www.linkedin.com/edu/school?id=20022" '
#  'class="fa fa-linkedin-square">LinkIn</a></li>\n'
#  '<li class="last leaf"><a href="https://www.youtube.com/CUJS" class="fa '
#  'fa-youtube">Youtube</a></li>\n'
#  '</ul>      </div>\n'
#  '      <div class="footer-image-nav menu-block">\n'
#  '        <ul class="menu nav"><li class="first leaf"><a '
#  'href="http://towcenter.org" class="tow-center image">Tow Center For Digital '
#  'Journalism</a></li>\n'
#  '<li class="leaf"><a href="http://brown.columbia.edu/" class="brown-institute '
#  'image" target="_blank">The Brown Institute for Media Innovation</a></li>\n'
#  '<li class="leaf"><a href="http://cjr.org" class="journalism-review '
#  'image">Columbia Journalism Review</a></li>\n'
#  '<li class="leaf"><a href="http://dartcenter.org" class="dart-center '
#  'image">Dart Center For Journalism &amp; Trauma</a></li>\n'
#  '<li class="leaf"><a href="/lipman-center" class="ira-lipman image">The Ira '
#  'A. Lipman Center for Journalism and Civil and Human Rights</a></li>\n'
#  '<li class="last leaf"><a href="/li-center" class="li-center image">Li Center '
#  'for Global Journalism</a></li>\n'
#  '</ul>      </div>\n'
#  '    </div>\n'
#  '    <div class="col-md-2">\n'
#  '      <div class="footer-button-nav hidden-xs menu-block">\n'
#  '        <ul class="menu nav"><li class="first leaf"><a '
#  'href="https://apply.jrn.columbia.edu/apply/">Apply</a></li>\n'
#  '<li class="last leaf"><a href="https://journalism.givenow.columbia.edu/#" '
#  'target="_blank">Support Us</a></li>\n'
#  '</ul>      </div>\n'
#  '      <div class="footer-social-nav hidden-xs menu-block">\n'
#  '        <ul class="menu nav"><li class="first leaf"><a '
#  'href="https://www.facebook.com/columbiajournalism" class="fa '
#  'fa-facebook">Facebook</a></li>\n'
#  '<li class="leaf"><a href="https://twitter.com/columbiajourn" class="fa '
#  'fa-twitter">Twitter</a></li>\n'
#  '<li class="leaf"><a href="https://www.instagram.com/columbiajournalism/" '
#  'class="fa fa-instagram">Instagram</a></li>\n'
#  '<li class="leaf"><a href="https://www.linkedin.com/edu/school?id=20022" '
#  'class="fa fa-linkedin-square">LinkIn</a></li>\n'
#  '<li class="last leaf"><a href="https://www.youtube.com/CUJS" class="fa '
#  'fa-youtube">Youtube</a></li>\n'
#  '</ul>      </div>\n'
#  '    </div>\n'
#  '  </div>\n'
#  '\n'
#  '  <div class="row">\n'
#  '    <div class="col-md-12">\n'
#  '      <div class="footer-copyright-nav menu-block">\n'
#  '        <ul class="menu nav"><li class="first leaf hidden-sm '
#  'hidden-xs"><span class="nolink">© 2021 Columbia Journalism '
#  'School</span></li>\n'
#  '<li class="leaf"><a '
#  'href="/columbia-university-non-discrimination-statement-and-policy">Non-Discrimination '
#  'Policy</a></li>\n'
#  '<li class="leaf"><a href="/privacy-policy">Privacy Policy</a></li>\n'
#  '<li class="leaf"><a href="/site-map">Site Map</a></li>\n'
#  '<li class="leaf hidden-md hidden-lg"><a '
#  'href="http://www.columbia.edu/">Columbia University</a></li>\n'
#  '<li class="last leaf hidden-md hidden-lg"><span class="nolink">© 2021 '
#  'Columbia Journalism School</span></li>\n'
#  '</ul>      </div>\n'
#  '    </div>\n'
#  '  </div>\n'
#  '\n'
#  '</div>\n'
#  '          <div id="where-to-begin-menu">\n'
#  '        <div class="content">\n'
#  '          <a href="#" class="handle"><i class="fa fa-chevron-up"></i><i '
#  'class="fa fa-chevron-down"></i> Where to begin <i class="fa '
#  'fa-chevron-up"></i><i class="fa fa-chevron-down"></i></a>\n'
#  '          <ul class="menu nav"><li class="first leaf clearfix"><a '
#  'href="/deadlines-and-application-requirements"><span><img '
#  'src="/sites/all/themes/soj/assets/images/calendar.svg" alt="Deadlines & '
#  'Requirements"></span>Deadlines & Requirements</a><div class="desc">vary by '
#  'program. Check your dates.</div></li>\n'
#  '<li class="leaf clearfix"><a href="/cost-attendance"><span><img '
#  'src="/sites/all/themes/soj/assets/images/chart.svg" '
#  'alt="Tuition"></span>Tuition</a><div class="desc">planning starts '
#  'here.</div></li>\n'
#  '<li class="leaf clearfix"><a '
#  'href="/scholarships-and-financial-aid"><span><img '
#  'src="/sites/all/themes/soj/assets/images/info.svg" alt="Scholarships & '
#  'Financial Aid"></span>Scholarships & Financial Aid</a><div '
#  'class="desc">explained.</div></li>\n'
#  '<li class="leaf clearfix"><a '
#  'href="/frequently-asked-questions?tag=153"><span><img '
#  'src="/sites/all/themes/soj/assets/images/question.svg" alt="Frequently Asked '
#  'Questions"></span>Frequently Asked Questions</a><div '
#  'class="desc">answered.</div></li>\n'
#  '<li class="leaf clearfix"><a '
#  'href="https://apply.jrn.columbia.edu/register/stayconnected"><span><img '
#  'src="/sites/all/themes/soj/assets/images/paper.svg" alt="Request '
#  'Information"></span>Request Information</a><div class="desc">about our '
#  'programs.</div></li>\n'
#  '<li class="leaf clearfix"><a href="/meet-us"><span><img '
#  'src="/sites/all/themes/soj/assets/images/handshake.svg" alt="Meet With '
#  'Us"></span>Meet With Us</a><div class="desc">and attend an information '
#  'session.</div></li>\n'
#  '<li class="last leaf clearfix"><a '
#  'href="https://apply.jrn.columbia.edu/apply/"><span><img '
#  'src="/sites/all/themes/soj/assets/images/pen.svg" '
#  'alt="Apply"></span>Apply</a><div class="desc">Applications for the 2023-2024 '
#  'school year are now closed.</div></li>\n'
#  '</ul>        </div>\n'
#  '      </div>\n'
#  '      </footer>\n'
#  '  <script '
#  'src="https://journalism.columbia.edu/files/soj/js/js_MRdvkC2u4oGsp5wVxBG1pGV5NrCPW3mssHxIn6G9tGE.js"></script>\n'
#  '\n'
#  '  <script type="text/javascript">\n'
#  "    var _sf_async_config = { uid: 64062, domain: 'journalism.columbia.edu', "
#  'useCanonical: true };\n'
#  '    (function() {\n'
#  '      function loadChartbeat() { window._sf_endpt = (new Date()).getTime(); '
#  "var e = document.createElement('script'); e.setAttribute('language', "
#  "'javascript'); e.setAttribute('type', 'text/javascript'); "
#  "e.setAttribute('src','//static.chartbeat.com/js/chartbeat.js'); "
#  'document.body.appendChild(e); };\n'
#  '      var oldonload = window.onload;\n'
#  "      window.onload = (typeof window.onload != 'function') ?\n"
#  '      loadChartbeat : function()\n'
#  '      { oldonload(); loadChartbeat(); };\n'
#  '    })();\n'
#  '  </script>\n'
#  '  \n'
#  '  <!-- SessionCam Client Integration v6.0 -- INC1421525 / INC1437462 on '
#  '20190402-->\n'
#  '  <script type="text/javascript">\n'
#  '      //<![CDATA[\n'
#  "      var scRec=document.createElement('SCRIPT');\n"
#  "      scRec.type='text/javascript';\n"
#  '      '
#  'scRec.src="//d2oh4tlt9mrke9.cloudfront.net/Record/js/sessioncam.recorder.js"\n'
#  "      document.getElementsByTagName('head')[0].appendChild(scRec);\n"
#  '      //]]>\n'
#  '  </script>\n'
#  '  <!-- End SessionCam -->\n'
#  '</body>\n'
#  '</html>\n')

# %% [markdown]
# ### 2) Use `BeautifulSoup` to convert the HTML into its DOM representation

# %%
j_DOM = lxml.html.fromstring(page)
print(J_DOM)
# Out:
# <Element html at 0x11961fd30>

# %% [markdown]
# ### 3) Use `.select(...)` to select all elements representing a faculty member
#
# Assign the resulting elements to a variable named `faculty_els`.
#
# You'll want "View Source" or pop open the Element Inspector to figure out which elements to target.
#
# Note: An element's `class` attribute can contain *multiple* classes, separated by spaces. For example: `<div class="potato hamburger">Hello</div>` has two classes, `potato` and `hamburger`.
#
# A CSS selector for *either* of the classes — `soup.select(".potato")` *or* `soup.select(".hamburger")` — will both match that element.

# %%
faculty_els = j_DOM.cssselect(".views-row")
pp.pprint(faculty_els)
# Out:
# [<Element div at 0x11961df30>,
#  <Element div at 0x1197b1ee0>,
#  <Element div at 0x119372ca0>,
#  <Element div at 0x119786bb0>,
#  <Element div at 0x10caa13a0>,
#  <Element div at 0x1198649f0>,
#  <Element div at 0x119864c20>,
#  <Element div at 0x119864cc0>]

# %% [markdown]
# ### 4) Count the number of matching elements, using `len`
#
# Does it match the number of faculty you see on the page? (It should.)

# %%
len(faculty_els)
# Out:
# 8

# %% [markdown]
# ### 5) For each faculty member, print their name, title, and faculty page URL
#
# You'll want to construct a `for` loop. In each iteration of the loop, print out something that looks like this:
#
# ```
# Denise Ajiri's title is 'Adjunct Assistant Professor'. You can find more information about them @ /faculty/denise-ajiri
# ---
# ```
#
# You'll note that the "href" is not a complete URL, but rather a "[relative path](https://www.w3schools.com/html/html_filepaths.asp)". Don't worry too much about that for now, although you're welcome to try "solving" that part.

# %%
j_root_url = "https://journalism.columbia.edu"
j_names = J_DOM.cssselect("h2.title a")
j_titles = J_DOM.cssselect(".sub-title p")
j_list = []

for i in range(len(faculty_els)):
    d = {}
    
    name = j_names[i].text
    d['name'] = name
    
    title = j_titles[i].text_content() # can use .text or .text_content() method
    d['title'] = title
    
    link = j_root_url + j_names[i].attrib["href"]
    d['link'] = link

    j_list.append(d)
    blurb = f"\n{name}'s title is '{title}'. You can find more information about them @ {link}\n"
    print(blurb)
    print("---------------------------------------------\n")
# Out:
# Denise Ajiri's title is 'Adjunct Assistant Professor'. You can find more information about them @ https://journalism.columbia.edu/faculty/denise-ajiri
#
# ---------------------------------------------
#
#
# Andrea Fuller's title is 'Adjunct Faculty'. You can find more information about them @ https://journalism.columbia.edu/faculty/andrea-fuller
#
# ---------------------------------------------
#
#
# Robert Gebeloff's title is 'Adjunct Faculty'. You can find more information about them @ https://journalism.columbia.edu/faculty/robert-gebeloff
#
# ---------------------------------------------
#
#
# Mark Hansen's title is 'David and Helen Gurley Brown Professor of Journalism and Innovation; Director, David and Helen Gurley Brown Institute of Media Innovation'. You can find more information about them @ https://journalism.columbia.edu/faculty/mark-hansen
#
# ---------------------------------------------
#
#
# Tom  Meagher's title is 'Adjunct Faculty'. You can find more information about them @ https://journalism.columbia.edu/faculty/tom-meagher
#
# ---------------------------------------------
#
#
# Dhrumil Mehta's title is 'Associate Professor in Data Journalism; Deputy Director of the Tow Center for Digital Journalism'. You can find more information about them @ https://journalism.columbia.edu/faculty/dhrumil-mehta
#
# ---------------------------------------------
#
#
# Matt Rocheleau's title is 'Adjunct Faculty'. You can find more information about them @ https://journalism.columbia.edu/faculty/matt-rocheleau
#
# ---------------------------------------------
#
#
# Giannina Segnini's title is 'John S. and James L. Knight Professor of Professional Practice in Data Journalism'. You can find more information about them @ https://journalism.columbia.edu/faculty/giannina-segnini
#
# ---------------------------------------------

# %% [markdown]
# ### 6) Now, let's do the same thing, but storing the info in a `pandas` `DataFrame`
#
# Specifically, a `DataFrame` with the columns `name`, `title`, `href`.

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.from_records.html

df = pd.DataFrame.from_records(j_list)
df
# Out:
#                name                                              title  \
# 0      Denise Ajiri                        Adjunct Assistant Professor
# 1     Andrea Fuller                                    Adjunct Faculty
# 2   Robert Gebeloff                                    Adjunct Faculty
# 3       Mark Hansen  David and Helen Gurley Brown Professor of Jour...
# 4      Tom  Meagher                                    Adjunct Faculty
# 5     Dhrumil Mehta  Associate Professor in Data Journalism; Deputy...
# 6    Matt Rocheleau                                    Adjunct Faculty
# 7  Giannina Segnini  John S. and James L. Knight Professor of Profe...
#
#                                                 link
# 0  https://journalism.columbia.edu/faculty/denise...
# 1  https://journalism.columbia.edu/faculty/andrea...
# 2  https://journalism.columbia.edu/faculty/robert...
# 3  https://journalism.columbia.edu/faculty/mark-h...
# 4  https://journalism.columbia.edu/faculty/tom-me...
# 5  https://journalism.columbia.edu/faculty/dhrumi...
# 6  https://journalism.columbia.edu/faculty/matt-r...
# 7  https://journalism.columbia.edu/faculty/gianni...

# %% [markdown]
# ### 7) Using that `DataFrame`, calculate how many are "Adjunct Faculty"

# %%
adjunct1 = len(df[df.title == 'Adjunct Faculty'])
print(f"There are currently {adjunct1} adjuncts")

## OR !!!!!!

adjunct2 = len(df[df.title == 'Adjunct Faculty'].value_counts())
print(f"There are currently {adjunct2} adjuncts")
# Out:
# There are currently 4 adjuncts
# There are currently 4 adjuncts

# %% [markdown]
# ---
#
# ---
#
# ---
